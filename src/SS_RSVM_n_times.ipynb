# %%
import os
import random
import numpy as np
def seed_everything(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ["OMP_NUM_THREADS"] = "1"
    os.environ["MKL_NUM_THREADS"] = "1"
    os.environ["OPENBLAS_NUM_THREADS"] = "1"
    os.environ["VECLIB_MAXIMUM_THREADS"] = "1"
    os.environ["NUMEXPR_NUM_THREADS"] = "1"
    random.seed(seed)
    np.random.seed(seed)
SEED = 42
seed_everything(SEED)

import pandas as pd
import cvxpy as cp
import time
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_svmlight_file
from sklearn.svm import LinearSVC
from matplotlib.ticker import MaxNLocator
from sklearn.preprocessing import normalize

# %%
# Breast Cancer Wisconsin dataset
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
X = data.data
y = data.target

y = np.where(y == 1, 1, -1)

scaler = StandardScaler()
X_train2 = scaler.fit_transform(X)
y_train2 = y

# %% [markdown]
# **ROBUST SVM**

# %%
def train_robust_svm(
        X_train,
        y_train,
        C,
        rho,
        max_iters,
        eps,
        w_init=None,
        use_warm_start=True,
        verbose=False):

    n, d = X_train.shape

    # ----- variables -----
    w = cp.Variable(d)
    t = cp.Variable(nonneg=True)
    xi = cp.Variable(n, nonneg=True)

    y_cp = cp.Constant(y_train)
    rho_cp = cp.Constant(rho)

    # ----- constraints -----
    margin_constraint = (
        1 - cp.multiply(y_cp, X_train @ w)
        + cp.multiply(rho_cp, t)
        <= xi
    )

    soc_constraint = cp.SOC(t, w)

    constraints = [margin_constraint, soc_constraint]

    # ----- objective -----
    objective = cp.Minimize(
        0.5 * cp.square(t) +
        C * cp.sum(xi)
    )

    prob = cp.Problem(objective, constraints)

    # ===== Warm start initialization =====
    if w_init is not None:
        w.value = w_init
        t.value = np.linalg.norm(w_init)

        # khởi tạo xi gần feasible
        margins = y_train * (X_train @ w_init)
        xi.value = np.maximum(0, 1 - margins + rho * t.value)

    start = time.process_time()

    prob.solve(
        solver=cp.SCS,

        max_iters=max_iters,
        eps=eps,
        verbose=verbose,

        acceleration_lookback=1,
        normalize=False,

        warm_start=use_warm_start,

        rho_x=1e-6,
        scale=1e-3,
    )

    end = time.process_time()

    w_val = w.value
    xi_val = xi.value

    # dual variables
    alpha = margin_constraint.dual_value
    alpha = np.clip(alpha, 0, C)

    return w_val, alpha, end - start

# %% [markdown]
# **SAFE SCREENIG FOR ROBUST SVM**

# %%
# Screening
def screen(X, y, rho, w, R_val, indices, normX_all, Xw):

    idx_array = np.array(indices)

    y_sub = y[idx_array]
    rho_sub = rho[idx_array]
    normX_sub = normX_all[idx_array]

    margins = y_sub * Xw[idx_array]

    w_norm = np.linalg.norm(w)
    w_norm_minus_R = max(w_norm - R_val, 0.0)

    LB = margins - rho_sub*(w_norm + R_val) - R_val*normX_sub
    UB = margins - rho_sub*w_norm_minus_R + R_val*normX_sub

    mask_N = LB > 1.0
    mask_S = UB < 1.0

    N_k = set(idx_array[mask_N])
    S_k = set(idx_array[mask_S])
    F_k_new = set(idx_array[~(mask_N | mask_S)])

    return N_k, S_k, F_k_new

# Dynamic Safe Screening
def dynamic_safe_screening(X, y, rho, C,
                           tol_gap=1e-4, min_F_size=20,
                           initial_reltol=1e-2, final_reltol=1e-6,
                           max_reductions=6,
                           max_iters=2000,
                           verbose=True):
    n, d = X.shape
    normX_all = np.linalg.norm(X, axis=1)
    total_start = time.time()
    all_idx = np.arange(n)
    w_prev = np.zeros(d)

    if verbose:
        print(f"Iter 0: removed 0 |F|={n} |S|=0 |R|=0, gap={0.0} R0={0.0}")

    solve_history = [{
        'iter': 0,
        'F_size': n,
        'primal': 0,
        'dual': 0,
        'gap': 0,
        'Radius': 0,
        'reltol': None,
        'time': time.time()-total_start,
        'screening_rate': 0.0,
        'removed': 0
    }]

    # === Loop for Iter >=1: robust subproblems with screening
    F = set(all_idx)
    R, S = set(), set()
    iteration, reductions, stall_count = 1, 1, 0

    while len(F) > min_F_size and reductions < max_reductions:
        F_list = np.fromiter(F, dtype=int)
        reltol = max(initial_reltol * (0.1 ** reductions), final_reltol)

        # ----- Train robust SVM on F_list set -----
        w_new, alpha, _ = train_robust_svm(
            X_train=X[F_list],
            y_train=y[F_list],
            C=C,
            rho=rho[F_list],
            w_init=w_prev,
            use_warm_start=False,
            max_iters=max_iters,
            eps=reltol
        )
        w_prev = w_new

        # ----- xi, primal, dual và alpha -----
        Xw = X @ w_new
        Xw_F = Xw[F_list]
        X_F = X[F_list]
        y_F = y[F_list]
        rho_F = rho[F_list]
        t_new = np.linalg.norm(w_new)
        xi_new = np.maximum(0, 1 - y_F * Xw_F + rho_F * t_new)
        primal = 0.5 * t_new**2 + C * np.sum(xi_new)

        norm_d = np.linalg.norm(X_F.T @ (alpha * y_F))
        s = np.sum(alpha * rho_F)
        dual = np.sum(alpha) - 0.5 * max(norm_d - s, 0.0)**2

        if iteration == 1:
            gap = max(primal - dual, 1e-4)
        else:
            gap = max(primal - dual, 1e-12)
        R_val = max(np.sqrt(2.0 * gap), 1e-12)

        # ----- Screening -----
        R_k, S_k, F_new = screen(
            X, y, rho, w_new, R_val, F_list,
            normX_all, Xw=Xw
        )

        removed = len(F) - len(F_new)
        if removed == 0:
            stall_count += 1
        else:
            stall_count = 0
        if stall_count >= 6:
            break

        R.update(R_k)
        S.update(S_k)
        assert F_new.issubset(F)
        F = set(F_new)

        total_time_elapsed = time.time() - total_start
        screening_rate = (n - len(F)) / n

        solve_history.append({
            'iter': iteration,
            'F_size': len(F),
            'primal': primal,
            'dual': dual,
            'gap': gap,
            'Radius': R_val,
            'reltol': reltol,
            'time': total_time_elapsed,
            'screening_rate': screening_rate,
            'removed': removed
        })

        if verbose:
            print(f"Iter {iteration}: removed={removed} |F|={len(F)} |S|={len(S)} |R|={len(R)} gap={gap:.2e} R={R_val:.2e} rate={screening_rate:.3f}")

        if gap < tol_gap:
            break

        reductions += 1
        iteration += 1

    total_time = time.time() - total_start
    if verbose:
        print(f"\nDynamic screening finished: |F|={len(F)} |S|={len(S)} "
              f"|R|={len(R)} time={total_time:.4f}s")

    A = F.union(S)
    return {
        'A': A,
        'F': F,
        'S': S,
        'R': R,
        'R_val': R_val,
        'gap': gap,
        'time': total_time,
        'history': solve_history
    }

# %% [markdown]
# **RESULTS**

# %%
C_list = [0.01, 0.1, 1.0, 10.0]
rho_list = [0.0, 0.01, 0.02, 0.05]
n_runs = 100

all_results = []

for rho_val in rho_list:
    print(f"\n========== Running with rho = {rho_val} ==========")

    for C_val in C_list:
        print(f"\n--- Running with C = {C_val}, rho = {rho_val} ---")

        times_full = []
        times_safe = []
        elim_rates = []
        history_first = None

        for run in range(n_runs):

            rho_full = np.ones(len(y_train2)) * rho_val

            # Full Robust SVM
            w_full, b_full, time_full = train_robust_svm(
                X_train2, y_train2,
                C=C_val,
                rho=rho_full,
                max_iters=5_000_000,
                eps=1e-6,
                w_init=None
            )

            times_full.append(time_full)

            # Safe screening
            result_r = dynamic_safe_screening(
                X_train2, y_train2,
                rho=rho_full,
                C=C_val
            )

            if history_first is None:
                history_first = result_r["history"]

            elim_rate = len(result_r['R']) / len(y_train2)

            A_list_r = sorted(result_r['A'])
            X_train_A_r = X_train2[A_list_r]
            y_train_A_r = y_train2[A_list_r]
            rho_A_r = np.ones(len(y_train_A_r)) * rho_val

            # Train Active set
            w_A, b_A, time_A = train_robust_svm(
                X_train_A_r,
                y_train_A_r,
                C=C_val,
                rho=rho_A_r,
                max_iters=500,
                eps=1e-2
            )

            total_time_safe = time_A + result_r['time']

            times_safe.append(total_time_safe)
            elim_rates.append(elim_rate)

        mean_full = np.mean(times_full)
        std_full = np.std(times_full)

        mean_safe = np.mean(times_safe)
        std_safe = np.std(times_safe)

        mean_elim = np.mean(elim_rates)

        print(f"Full Robust SVM: {mean_full:.4f}s ± {std_full:.4f}")
        print(f"Safe Screening: {mean_safe:.4f}s ± {std_safe:.4f}")
        print(f"Elimination rate: {mean_elim:.2%}")

        all_results.append({
            "rho": rho_val,
            "C": C_val,
            "time_full_mean": mean_full,
            "time_full_std": std_full,
            "time_safe_mean": mean_safe,
            "time_safe_std": std_safe,
            "elim_rate": mean_elim,
            "history": history_first
        })
# Out:
# ========== Running with rho = 0.0 ==========
#
# --- Running with C = 0.01, rho = 0.0 ---
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2686s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1901s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1700s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1722s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1793s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1709s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1862s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2472s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1680s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1969s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1686s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1715s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1715s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1847s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2006s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2589s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2789s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1832s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1795s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1814s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1767s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1688s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1784s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2319s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2470s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1712s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1700s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1802s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1847s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1766s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1713s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1726s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2515s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1716s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1862s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1704s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1703s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1711s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1828s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1714s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2561s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2574s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1693s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1739s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1703s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1828s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1714s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1691s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1972s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2523s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1719s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1827s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1738s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1690s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1701s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1739s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1711s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2552s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2596s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1761s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1703s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1761s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1706s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1770s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1848s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1976s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2503s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1835s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1705s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1714s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1943s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1723s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1760s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1732s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2815s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1903s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1690s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1708s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1843s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1852s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1833s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1753s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2626s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2624s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1838s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1702s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1780s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1730s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1744s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1761s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1741s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2591s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1774s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1719s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1723s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1799s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1713s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1753s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.1706s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=484 |F|=85 |S|=92 |R|=392 gap=1.13e-03 R=4.75e-02 rate=0.851
# Iter 2: removed=72 |F|=13 |S|=137 |R|=419 gap=3.81e-06 R=2.76e-03 rate=0.977
#
# Dynamic screening finished: |F|=13 |S|=137 |R|=419 time=0.2577s
# Full Robust SVM: 1.3373s ± 0.1752
# Safe Screening: 0.2123s ± 0.0351
# Elimination rate: 73.64%
#
# --- Running with C = 0.1, rho = 0.0 ---
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# /usr/local/lib/python3.12/dist-packages/cvxpy/problems/problem.py:1510: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.5056s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4893s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.7283s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.5009s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4977s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4939s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.7346s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4945s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.5012s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4983s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.7423s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4954s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4940s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4929s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.7180s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4970s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4996s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4927s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4934s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4942s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4998s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=164 |F|=405 |S|=0 |R|=164 gap=1.47e+00 R=1.72e+00 rate=0.288
# Iter 2: removed=237 |F|=168 |S|=1 |R|=400 gap=3.82e-01 R=8.74e-01 rate=0.705
# Iter 3: removed=140 |F|=28 |S|=9 |R|=532 gap=4.93e-03 R=9.93e-02 rate=0.951
# Iter 4: removed=13 |F|=15 |S|=9 |R|=545 gap=2.17e-05 R=6.59e-03 rate=0.974
#
# Dynamic screening finished: |F|=15 |S|=9 |R|=545 time=0.4894s
# Full Robust SVM: 2.8535s ± 0.3012
# Safe Screening: 0.5513s ± 0.0882
# Elimination rate: 95.78%
#
# ========== Running with rho = 0.02 ==========
#
# --- Running with C = 0.01, rho = 0.02 ---
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.2691s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1708s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1715s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1772s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1724s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.2614s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1700s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1897s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1750s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1741s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1743s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.2647s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1735s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1807s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1706s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1722s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1717s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.2633s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1824s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1850s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1842s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1840s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1823s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.2450s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1730s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1784s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1801s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1714s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1702s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.2533s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1710s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1719s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1705s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1720s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1891s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.2543s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1777s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1717s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=477 |F|=92 |S|=90 |R|=387 gap=1.48e-03 R=5.44e-02 rate=0.838
# Iter 2: removed=76 |F|=16 |S|=138 |R|=415 gap=1.02e-05 R=4.51e-03 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=138 |R|=415 time=0.1716s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# ...
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5200s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5174s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5147s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5113s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5075s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.7439s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.7503s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5012s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4974s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4966s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4989s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4950s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4984s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4990s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5031s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4954s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.7413s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.7348s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4984s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5163s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5091s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5088s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5098s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5141s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5165s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5317s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5240s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.7436s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.7548s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4978s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4992s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4959s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5106s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5010s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5027s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5134s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.4949s
# Iter 0: removed 0 |F|=569 |S|=0 |R|=0, gap=0.0 R0=0.0
# Iter 1: removed=95 |F|=474 |S|=0 |R|=95 gap=2.13e+00 R=2.06e+00 rate=0.167
# Iter 2: removed=318 |F|=156 |S|=2 |R|=411 gap=3.53e-01 R=8.41e-01 rate=0.726
# Iter 3: removed=127 |F|=29 |S|=9 |R|=531 gap=1.03e-02 R=1.43e-01 rate=0.949
# Iter 4: removed=13 |F|=16 |S|=10 |R|=543 gap=2.48e-04 R=2.23e-02 rate=0.972
#
# Dynamic screening finished: |F|=16 |S|=10 |R|=543 time=0.5194s
# Full Robust SVM: 0.6200s ± 0.0791
# Safe Screening: 0.5634s ± 0.0926
# Elimination rate: 95.43%

# %%
def plot_screening_progress_overlay(all_results, rho_list, C_list):

    blue_colors = ["#BDD7E7","#6BAED6","#3182BD","#08519C"]

    fig, axes = plt.subplots(1, len(rho_list), figsize=(20,4), sharey=True)

    if len(rho_list) == 1:
        axes = [axes]

    legend_handles = None

    for i, rho_val in enumerate(rho_list):

        ax = axes[i]

        for j, C_val in enumerate(C_list):

            result = [
                r for r in all_results
                if r["rho"] == rho_val and r["C"] == C_val
            ][0]

            history = result["history"]

            iterations = [h["iter"] for h in history]
            rates = [h["screening_rate"] for h in history]

            line, = ax.plot(
                iterations,
                rates,
                marker='o',
                linewidth=2.5,
                color=blue_colors[j],
                label=rf"$C={C_val}$"
            )

        if i == 0:
            legend_handles, legend_labels = ax.get_legend_handles_labels()

        ax.set_title(rf"$\rho = {rho_val}$", fontsize=20)
        ax.set_xlabel("Iteration")

        if i == 0:
            ax.set_ylabel("Screening rate")

        ax.grid(True, linestyle="--", alpha=0.5)
        ax.xaxis.set_major_locator(MaxNLocator(integer=True))

    fig.legend(
        legend_handles,
        legend_labels,
        loc="upper center",
        ncol=len(C_list),
        frameon=False,
        fontsize=14,
        bbox_to_anchor=(0.5,1.0)
    )

    plt.ylim(-0.1,1.1)
    plt.tight_layout(rect=[0,0,1,0.92])
    plt.savefig("screeningrate_cancer.pdf", bbox_inches="tight")

plot_screening_progress_overlay(all_results, rho_list, C_list)

# %%
def plot_time_comparison(all_results, rho_list, C_list):

    plt.style.use("seaborn-v0_8-whitegrid")

    fig, axes = plt.subplots(
        1, len(rho_list),
        figsize=(24, 5),
        sharey=True
    )

    color_full = "#D5DBDB"
    color_safe = "#3498DB"

    legend_handles = None

    for idx, rho_val in enumerate(rho_list):

        fig.subplots_adjust(wspace=0.12)
        ax = axes[idx]

        results_rho = [res for res in all_results if res["rho"] == rho_val]
        results_rho = sorted(results_rho, key=lambda x: x["C"])

        # ===== lấy mean + std =====
        times_noscreen = [res["time_full_mean"] for res in results_rho]
        std_noscreen   = [res["time_full_std"]  for res in results_rho]

        times_screen = [res["time_safe_mean"] for res in results_rho]
        std_screen   = [res["time_safe_std"]  for res in results_rho]

        x = np.arange(len(C_list))
        width = 0.38

        bars1 = ax.bar(
            x - width/2,
            times_noscreen,
            width,
            yerr=std_noscreen,
            capsize=4,
            label="Non-screen",
            color=color_full,
            edgecolor="white",
            linewidth=1.2
        )

        bars2 = ax.bar(
            x + width/2,
            times_screen,
            width,
            yerr=std_screen,
            capsize=4,
            label="Screen",
            color=color_safe,
            edgecolor="white",
            linewidth=1.2
        )

        if idx == 0:
            legend_handles, legend_labels = ax.get_legend_handles_labels()

        ax.set_xticks(x)
        ax.set_xticklabels([f"C={c}" for c in C_list], fontsize=18)

        ax.set_title(
            rf"$\rho = {rho_val}$",
            fontsize=24,
            weight="bold"
        )

        if idx == 0:
            ax.set_ylabel("Time (s)", fontsize=24)

        ax.grid(True, axis="y", linestyle="--", alpha=0.4)

        ax.spines["top"].set_visible(True)
        ax.spines["right"].set_visible(True)
        ax.spines["left"].set_color("#CCCCCC")
        ax.spines["bottom"].set_color("#CCCCCC")

    fig.legend(
        legend_handles,
        legend_labels,
        loc="upper center",
        ncol=2,
        frameon=False,
        fontsize=18,
        bbox_to_anchor=(0.5, 1.02)
    )

    plt.tight_layout(rect=[0.02, 0, 0.98, 0.93])

    plt.savefig(
        "time_cancer.pdf",
        bbox_inches="tight"
    )

    plt.show()

plot_time_comparison(all_results, rho_list, C_list)

# %%
def extract_time_and_elim_table(all_results, rho_list, C_list):

    rows = []

    for rho_val in rho_list:
        for C_val in C_list:

            result = [
                res for res in all_results
                if res["rho"] == rho_val and res["C"] == C_val
            ][0]

            time_full_mean = result["time_full_mean"]
            time_full_std  = result["time_full_std"]

            time_safe_mean = result["time_safe_mean"]
            time_safe_std  = result["time_safe_std"]

            elim_rate = result["elim_rate"]

            speedup = (
                time_full_mean / time_safe_mean
                if time_safe_mean > 0 else np.nan
            )

            rows.append([
                rho_val,
                C_val,
                time_full_mean,
                time_full_std,
                time_safe_mean,
                time_safe_std,
                speedup,
                elim_rate
            ])

    df = pd.DataFrame(
        rows,
        columns=[
            "rho",
            "C",
            "Non-screen mean",
            "Non-screen std",
            "Screen mean",
            "Screen std",
            "Speedup",
            "Elimination Rate"
        ]
    )

    return df

df = extract_time_and_elim_table(all_results, rho_list, C_list)

# %%
df["Non-screen"] = (
    df["Non-screen mean"].map("{:.3f}".format)
    + " ± "
    + df["Non-screen std"].map("{:.3f}".format)
)

df["Screen"] = (
    df["Screen mean"].map("{:.3f}".format)
    + " ± "
    + df["Screen std"].map("{:.3f}".format)
)

df_display = df[
    ["rho", "C", "Non-screen", "Screen", "Speedup", "Elimination Rate"]
]

print(df_display)
# Out:
#      rho      C     Non-screen         Screen    Speedup  Elimination Rate
# 0   0.00   0.01  1.337 ± 0.175  0.212 ± 0.035   6.298389          0.736380
# 1   0.00   0.10  7.339 ± 0.398  0.370 ± 0.056  19.813146          0.896309
# 2   0.00   1.00  1.979 ± 0.229  0.377 ± 0.060   5.253842          0.943761
# 3   0.00  10.00  0.630 ± 0.082  0.367 ± 0.057   1.713780          0.961336
# 4   0.01   0.01  1.705 ± 0.215  0.233 ± 0.036   7.326956          0.729350
# 5   0.01   0.10  3.231 ± 0.325  0.374 ± 0.058   8.634178          0.892794
# 6   0.01   1.00  3.496 ± 0.342  0.428 ± 0.069   8.167136          0.942004
# 7   0.01  10.00  2.854 ± 0.301  0.551 ± 0.088   5.175632          0.957821
# 8   0.02   0.01  2.005 ± 0.245  0.214 ± 0.036   9.349891          0.729350
# 9   0.02   0.10  3.823 ± 0.350  0.391 ± 0.061   9.784203          0.882250
# 10  0.02   1.00  3.341 ± 0.324  0.484 ± 0.077   6.898000          0.938489
# 11  0.02  10.00  0.967 ± 0.127  0.487 ± 0.073   1.986741          0.961336
# 12  0.05   0.01  0.907 ± 0.123  0.241 ± 0.039   3.767184          0.731107
# 13  0.05   0.10  2.773 ± 0.296  0.422 ± 0.065   6.576590          0.884007
# 14  0.05   1.00  3.601 ± 0.341  0.420 ± 0.065   8.568017          0.936731
# 15  0.05  10.00  0.620 ± 0.079  0.563 ± 0.093   1.100545          0.954306
